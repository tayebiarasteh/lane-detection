# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from skimage.io import imshow

# User imports
from config import sim_config
from simulator.simulator import simulate_road_img

# %%
# Use this notebook to test your simulator code during development
# It is up to you how you test your code - however, we encourage you
# to spend some thought on designing good test cases, as it will help
# you in developing robust code and avoiding tedious debugging sessions.
# For some inspiration on this topic you may want to check out for example
# https://en.wikipedia.org/wiki/Test-driven_development
# and/or the references therein.

# It is recommended to use one notebook cell per test case.
# Below you find an example for an end-to-end test

params=sim_config()

img1,_=simulate_road_img(params['simulator'])
img2,_=simulate_road_img(params['simulator'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,10))
ax1.imshow(img1)
ax2.imshow(img2)
plt.show()
# Out:
# [[1.1366426424776954, 0.37663956182592856], [0.13664264247769542, 0.8157636856261641]]
# [[[1.1385761384292135, 0.3757905171103469], [0.13857613842921354, 0.8149146409105823]], [[1.1177773080286217, 0.5649237852860765], [0.11777730802862171, 1.004047909086312]], [[1.1360552598119742, 0.5868974957243489], [0.13605525981197414, 1.0260216195245844]], [[1.1303674907116583, 0.769395132346903], [0.13036749071165826, 1.2085192561471385]]]
# ('salam', [[1.1366426424776954, 0.37663956182592856], [0.13664264247769542, 0.8157636856261641], [0.13664264247769542, 1.2157636856261642], [1.1366426424776954, 0.7766395618259285]])
# [[0.9166361427945829, 0.21062871264506522], [-0.08336385720541709, 0.13856594646673503]]
# [[[0.899549689514224, 0.20939741555750577], [-0.10045031048577599, 0.13733464937917558]], [[0.9031978354880429, 0.3896603110478015], [-0.09680216451195715, 0.31759754486947134]], [[0.9180468882831445, 0.4207303748673446], [-0.0819531117168555, 0.3486676086890144]], [[0.9329033259538433, 0.601800970861451], [-0.0670966740461567, 0.5297382046831209]]]
# ('salam', [[0.9166361427945829, 0.21062871264506522], [-0.08336385720541709, 0.13856594646673503], [-0.08336385720541709, 0.5385659464667351], [0.9166361427945829, 0.6106287126450652]])
